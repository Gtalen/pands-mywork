# %% [markdown]
# ***
# # Analysis of the Palmer Archipelago Penguins Dataset with Python
# ## Author: Ebelechukwu Chidimma Igwagu
# ***

# %% [markdown]
# <div>
# <img src = 'https://editor.analyticsvidhya.com/uploads/96124penguins.png', width = height = '400/'>
# </div>
#
# Photocredit: Artwork by [Alison Horst](https://editor.analyticsvidhya.com/uploads/96124penguins.png)

# %% [markdown]
# ## PROJECT AIM
# This project demonstrated analytical tools and processes involved in sourcing, investigating, exploring and visualizing data to provide valuable insights.

# %% [markdown]
# ## BACKGROUND
# The [Palmer penguins dataset](https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv) is a popular dataset that is made available by [Dr Kirsten Gorman](https://www.uaf.edu/cfos/people/faculty/detail/kristen-gorman.php) and the [Palmer Station Antarctica Long term ecological research network](https://pallter.marine.rutgers.edu/). Seven measurements from 344 male and female penguins make up this dataset and every row represent an individual penguin. The dataset's three species of penguins reside on three different islands. The penguin species, Adelie, Gentoo, and Chinstrap are found in the Biscoe, Dream, and Torgerson Islands in the Palmer Archipelago, Antarctica. the measured variables were species, island, sex, bill length, bill depth, flipper length and body mass. The dataset can be accessed [here](https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv) and was analysed using python.

# %% [markdown]
# ### Data modelling
#
# Data modelling is the process involved in extracting meaningful information from raw data by using visual representation of part or the whole dataset to communicate the connections between the data points and structure ([IBM](https://www.ibm.com/topics/data-modeling#:~:text=Data%20modeling%20is%20the%20process%20of%20creating%20a,to%20communicate%20connections%20between%20data%20points%20and%20structures.)).
#
# ##### Considerations for choosing the statistical models
# - Project Aim
# - Data Structure: The data type are object and float.
# - Variable Types in the dataset: The dataset has 4 numerical and 3 categorical variables
#
# ##### **Statistical Models**
#
# 1. **Descriptives:** This was used to provide a general summary of the palmer penguin dataset at the exploration phase.
# - **Categorical variables:** Summary statistics and Barchart was usedto provide a quick overview of the frequency of occurrence of the data subset. This was used for species, sex and island.
# - **Numerical variables:** Summary statistics, histogram to provides visualization of the frequency of occurence and normality of the dataset. This was used for bill length, bill depth, flipper length, mass versus sepecies, sex and island.
# - **Boxplot:** This was used for visual detection of outliers in the dataset.
#
# 2. **Correlation Analysis:** This was used to test the relationship between flipper length and body mass.
# -  **Scatterplots:** To detect the relationship between two numerical variables; flipper length and body mass.
# - **Heatmap correlation matrix:** This was used to compare the relationship between all the numerical variables in the dataset.
# - **Pairplots:** This was used to plot the pairwise relationships in the palmer penguin dataset.
#
# 3. **Regression Analysis:** This ws used for  testing relationship between flipper length and body mass and predicting how each affect the other. Body mass was the dependent variable and flipper length the independent variable.

# %% [markdown]
# ### Libraries/Prerequisites
#
# The analysis started off by importing the necessary libraries needed for data exploration, manipulation, analysis and visualization. Pandas was used for exploring the dataframe, Numpy numerical arrays for data visualization, Matplotlib and Seaborn for plotting data and Scipy for statistical testing.

# %%
#importing the libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
sns.set_theme()            #setting seaborn as default style for plots when using matplotlib

# %% [markdown]
# ### Laoding the dataset
# After importing the necessary libraries, the Palmer penguin dataset was loaded from [here](https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv) to the variable palmer_penguins and viewed.

# %% [markdown]
# ## Data Exploration
# The first step step was a quick glance through the data using the data head and tail functions. These provided a glimpse of the first and last five rows of the dataset respectively.

# %%
#importing the raw data

palmer_penguins = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv")
palmer_penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %%
# diplaying the first 5 rows of the dataset

palmer_penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
# displaying the last 5 rows of the dataset
print (palmer_penguins.tail())
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE

# %% [markdown]
# ### Scrolling through the dataset
# The to_string function was used to present the data in a scrollable format to get a scroll through the entire dataset.

# %%
#converts the data set to string and presents it in a scrollable pattern
print (palmer_penguins.to_string())
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g     sex
# 0       Adelie  Torgersen            39.1           18.7              181.0       3750.0    MALE
# 1       Adelie  Torgersen            39.5           17.4              186.0       3800.0  FEMALE
# 2       Adelie  Torgersen            40.3           18.0              195.0       3250.0  FEMALE
# 3       Adelie  Torgersen             NaN            NaN                NaN          NaN     NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0       3450.0  FEMALE
# 5       Adelie  Torgersen            39.3           20.6              190.0       3650.0    MALE
# 6       Adelie  Torgersen            38.9           17.8              181.0       3625.0  FEMALE
# 7       Adelie  Torgersen            39.2           19.6              195.0       4675.0    MALE
# 8       Adelie  Torgersen            34.1           18.1              193.0       3475.0     NaN
# ...

# %% [markdown]
# ### Data Structure
#  The data information showed that the dataset has 7 variables, 3 of which are of the object data type and 4 of the float type. Two out of the 344 measured bill length, bill depth, flipper length and body mass were shown to be of the null type and 11 out of the sex variable.

# %%
# displays infromation on the data types and count

palmer_penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Palmer Penguins measured variable and types
#
# 1. Species               - Categorical
# 2. Island                - Categorical
# 3. Bill length (mm)      - Numerical
# 4. Bill depth (mm)       - Numerical
# 5. Flipper length (mm)   - Numerical
# 6. Body mass (g)         - Numerical
# 7. Sex                   -Categorical

# %% [markdown]
# ### Descriptive Summary  of the Palmer Penguin Dataset

# %% [markdown]
# The next stage of the data exploration was summarizing the data using descriptive statistics. The dataset consist of penguins(n = 344) located in three different islands namely Biscoe (n = 168), Dream (n = 124) and Torgersen (n = 52). The penguins are of three different species Adelie (n = 152), Gentoo (n = 124) and Chinstrap (n = 68). These included male (n = 168), female (n = 165) and other penguins with missing entries for the sex variable (n = 8.).

# %% [markdown]
# #### Categorical Variable Summary

# %%
# Counting the penguin species
palmer_penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
#Counting the penguin species
palmer_penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Counting the sex of the penguins
palmer_penguins['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %% [markdown]
# #### Barcharts
#  This is great for plotting and counting occurrences in categorical variables.

# %%
# Grouping the data and counting the occurrences of each subgroup
species_island_counts = palmer_penguins.groupby(['species', 'island']).size().unstack()
island_sex_counts = palmer_penguins.groupby(['island', 'sex']).size().unstack()
sex_species_counts = palmer_penguins.groupby(['sex', 'species']).size().unstack()
species_sex_counts = palmer_penguins.groupby(['species', 'sex']).size().unstack()

# Setting up the subplots
fig, ax = plt.subplots(2, 2, figsize=(14, 8))  # 3 rows, 1 column
fig.suptitle('Palmer Penguins Categorical Variable barchart')

# Plot 1: Species barplot with stacked bars
species_island_counts.plot(kind='barh', stacked=True, ax=ax[0,0])
ax[0, 0].set_title('Palmer Penguins Species')

# Plot 2: Sex barplot with stacked bars
sex_species_counts.plot(kind='barh', stacked=True, ax=ax[0, 1])
ax[0, 1].set_title('Palmer Penguins Sex')

# Plot 3: Island barplot with stacked bars
island_sex_counts.plot(kind='barh', stacked=True, ax=ax[1, 0])
ax[1, 0].set_title('Palmer Penguins Island')

# Plot 3: Sex barplot with stacked bars
species_sex_counts.plot(kind='barh', stacked=True, ax=ax[1, 1])
ax[1, 1].set_title('Palmer Penguins Sex')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Barchart Summary

# %% [markdown]
#  The **palmer penguins species barchart**  above showed that the Adelie penguins has the highest population in the dataset, followed by the Gentoo penguins and then the Chinstrap penguins. The Adelie penguins were from all three Islands; Togerson, Dream and Biscoe. The Chinstrap Penguins were only from the dream island while the gentoo penguins were from the biscoe island. This finding is is in agreement with a analysis report on the Palmer penguin dataset ([Fortune, 2022](https://medium.com/@Fortune_/visualizing-the-palmerpenguins-dataset-d3d70bb619b4.)).
#
#  This raises the question on the impact of environmental factors in penguins habitat adaptation. Do Adelie penguin has disticnt features from Gentoo and Chinstrap that enables it to adapt to all three Islands?. Hopefully, the answer will be somewhere within the dataset.
#
#   The **Palmer penguins sex and island barchart** showed almost equal proportion of male to female penguins across the three species from all three islands with the male penguin populatiion being slightly higher.

# %% [markdown]
# ### Limitations of graphical representation: *Is graphical representation of data ideal?*
# Graphical representation is not the fastest in getting the actual count of the subsets in a datset, an absolute value count would be prefferable. The barchart above requires a bit of an effort in getting the absolute count of each of the subsets: "*How many Adelie penguins are from the Togerson Island?*".

# %%
# Setting up the subplots
fig, ax = plt.subplots(1, 3, figsize=(14, 7))
fig.suptitle('Palmer Penguins Categorical Variable barchart')

# Plot 1 Species countplot by Island
sns.countplot(data=palmer_penguins, x='species', hue='island', ax=ax[0])
ax[0].set_title('Palmer Penguins Species by Island')

# Plot 2: Island countplot by Sex
sns.countplot(data=palmer_penguins, x='island', hue='sex', ax=ax[1])
ax[1].set_title('Palmer Penguins Island by Sex')

# Plot 3: Sex countplot with hue Species
sns.countplot(data=palmer_penguins, x='sex', hue='species', ax=ax[2])
ax[2].set_title('Palmer Penguins Sex by Species')

# Adjust layout
plt.tight_layout()

# %% [markdown]
# The second barchart above is better for the subsets though still not ideal for the absolute total count for each category: "*What is the total number of female penguins in the palmer penguin dataset?"*.

# %% [markdown]
# #### Summary Statistics of the Palmer penguins' numerical variables
# The table below is the summary statistics for the bill length, bill depth, flipper length and body mass of the penguins;

# %%
# Palmer penguins descriptives for numerical variables
palmer_penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# #### Univariate Analysis
# A hisogram of the numerical variables was plotted to understand the distribution of the dataset. This has been reported by [Yash](https://medium.com/codex/exploratory-data-analysis-a-roadmap-for-cleaning-3e01a0d694) to be an important aspect of exploratory data analysis.

# %%
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Palmer Penguins numerical variable Histogram')

#creating a histplot for the numerical variables
sns.histplot(data=palmer_penguins, x='bill_length_mm', hue='species',  multiple='stack', kde=True, ax = ax [0, 0])
sns.histplot(data=palmer_penguins, x='bill_depth_mm', hue='species',   multiple='stack', kde=True, ax = ax [0, 1])
sns.histplot(data=palmer_penguins, x='flipper_length_mm',hue='species',multiple='stack', kde=True, ax = ax [1, 0])
sns.histplot(data=palmer_penguins, x='body_mass_g', hue='species', multiple='stack',kde=True, ax = ax [1, 1])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# #### Histogram summary by species
# The KDE plot shows a normal distribution for the bill length, bill depth, flipper length and body mass.
#
# - **Bill length:** There is an overlap in the bill length of the Gentoo and Chinstrap penguins while the Adelie penguins has shorter bill length.
#
# - **Bill depth:** Gentoo penguin has the shortest bill depth while there is an overlap in the measured bill depth of the Adelie and Chintrap penguins.
#
# - **Flipper length:** Gentoo has the longest flipper length while the Adelie and Chintrap penguins flipper length overlapped.
#
# - **Body mass:** Gentoo penguins wighed the most of all three species while the Adelie and Chintrap shared similar weight across the dataset.
#
# These finding are in agreement with a similar analysis result reported by [Allen Downey](https://allendowney.github.io/ThinkBayes2/chap12.html).
#
# #### *Can penguins be classified based on these features?*
# The Gentoo penguins has the shortest bill length, the longest flipper length and weighed the most of all three species.This can help in differentiating it from Adelie and the Chinstrap. It will be more difficult differentiating between the Adelie and Chinstrap due to the overlap in features though the shorter bill length can serve as a distinguishing feature for the Adelie penguins.
#
# In summary, penguins can possibly be classified and identified using their bill length, bill depth, flipper length and body mass.

# %%
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Palmer Penguins numerical Data vs Sex Histogram')

#creating a histplot for the numerical variables
sns.histplot(data=palmer_penguins, x='bill_length_mm', hue='sex', multiple='stack', kde=True, ax = ax [0, 0])
sns.histplot(data=palmer_penguins, x='bill_depth_mm', hue='sex', multiple='stack', kde=True, ax = ax [0, 1])
sns.histplot(data=palmer_penguins, x='flipper_length_mm',hue='sex',multiple='stack', kde=True, ax = ax [1, 0])
sns.histplot(data=palmer_penguins, x='body_mass_g', hue='sex', multiple='stack',kde=True, ax = ax [1, 1])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# #### Histogram summary of the Palmer penguins numeerical variable by sex
#
# From the histogram, it can be deduced that male penguins in the dataset have longer bill length, flipper length and wider bill depth than the female penguins. The males penguins also weighed more than the females. The KDE plot is bell shaped as seen with normal distribution. This could be useful in distinguishing between a male and a female penguin.

# %%
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Palmer Penguins numerical Data vs Island Histogram')

#creating a histplot for the numerical variables
sns.histplot(data=palmer_penguins, x='bill_length_mm', hue='island', multiple='stack', kde=True, ax = ax [0, 0])
sns.histplot(data=palmer_penguins, x='bill_depth_mm', hue='island', multiple='stack', kde=True, ax = ax [0, 1])
sns.histplot(data=palmer_penguins, x='flipper_length_mm',hue='island',multiple='stack', kde=True, ax = ax [1, 0])
sns.histplot(data=palmer_penguins, x='body_mass_g', hue='island', multiple='stack',kde=True, ax = ax [1, 1])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# #### Histogram summary of the Palmer penguins numerical variable by Island
# The histogram above showed a cluster of penguins with the same similarities of bill length, bill depth, flipper length and body mass across all three islands. To be identify the specie, a classification could be predicted using the cluster results;
#
# bill length cluster : Shortest bill length
# bill depth cluster: longest bill depth
# flipper length cluster: shorter and midpoint
# body mass cluster: weighs less and midpoint
#
# Comparing the finding with the **histogram summary by species** shows that these are likely the Adelie sspecies.

# %% [markdown]
# ## Data Cleaning and  Manipulation
# A copy of the original data was created before cleaning up the data as to ensure that the integrity of the original data was preserved.  Scrolling through the datasets showed that the nulltype data also known as missing values were depicted in the pandas datatframe with NAN (Not a number).
# Missing values in a dataset may lead to analytical errors so it is essential that these are dealt with efficiently ([Datacamp]https://www.datacamp.com/tutorial/techniques-to-handle-missing-data-values)).

# %%
# Creating a copy of the dataset before manipulating the data
penguins = palmer_penguins.copy()

# %% [markdown]
# Missing values were identified using the 'isna function'. This showed that the sex column has the highest number of missing values while rows' 3 and 339 were missing a lot of variables awhich may be due to incomplete entries.

# %%
# Checking for missings values in the dataset

penguins.isna().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# Selecting all the rows with NAN in the penguins dataset
penguins[penguins.isna().any(axis=1)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# ...

# %% [markdown]
# ### Dealing with missing values
# The sex column has the highest number of missing values while rows' 3 and 339 were missing a lot of variables and may be incomplete entries. The NAN in the sex column was replaced by data imputation  with the mode ([Datacamp](https://www.datacamp.com/tutorial/techniques-to-handle-missing-data-values)) while rows 3 and 339 were dropped.

# %%
# Finding the mode
print (penguins['sex'].mode()[0])

# Replacing the NAN in the sex column with the mode 

penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])
# Out:
# MALE

# %%
#rerunning the isna showed that only two rows has the NAN
penguins[penguins.isna().any(axis=1)]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g   sex
# 3            NaN  MALE
# 339          NaN  MALE

# %%
# Dropping the rows with multiple NAN

penguins = penguins.dropna()
penguins                     # Recheck: 342 rows by 7 columns as against the original 344 rows by 7 columns
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# ...

# %% [markdown]
# ### Dealing with duplicates
# The palmer penguin dataset was checked for duplicate rows and non was found.

# %%
# Checking for duplicates      
print (penguins.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Dealing with Outliers
# #### Boxplot
#
# The boxplot identified six numerical measurements to be outliers within the palmer penguin species. One outlier each for the Gentoo Penuins' bill length measurement and one for the Adelie Penguins' bill depth. The remaining four  each were two meeasurements each for flipper length and body mass for Adelie and Chinstrap species respectively.

# %%
# Boxplot
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Palmer Penguins Dataset Box plots')

#creating chart for each subplot
#plot 1: row 1, column 1
sns.boxplot(data=penguins, x='species', y='bill_length_mm', ax = ax [0, 0])

#plot 2: row 1, column 2
sns.boxplot(data=penguins, x='species', y='bill_depth_mm', ax = ax [0, 1])

#plot 3: row 2, column 1
sns.boxplot(data=penguins, x='species', y='flipper_length_mm', ax = ax [1, 0])

#plot 4: row 2, column 2
sns.boxplot(data=penguins, x='species', y='body_mass_g', ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
# Boxplots with the outliers removed
fig, ax = plt.subplots(2, 2, figsize = (13, 8))
fig.suptitle ('Palmer Penguins Dataset Box plots excluding outliers')

#plotting each subplots
#plot 1: row 1, column 1
sns.boxplot(data=penguins, x='species', y='bill_length_mm', showfliers = False, ax = ax [0, 0])

#plot 2: row 1, column 2
sns.boxplot(data=penguins, x='species', y='bill_depth_mm', showfliers = False,ax = ax [0, 1])

#plot 3: row 2, column 1
sns.boxplot(data=penguins, x='species', y='flipper_length_mm', showfliers = False, ax = ax [1, 0])

#plot 4: row 2, column 2
sns.boxplot(data=penguins, x='species', y='body_mass_g', showfliers = False, ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# #### Slicing the dataset for Z-score analysis on the subsets of the species

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       151
# Gentoo       123
# Chinstrap     68
# Name: count, dtype: int64

# %%
#slicing and saving the Adelie species to a new variable
penguins_Adelie = penguins[penguins['species']=='Adelie']
penguins_Adelie.value_counts()   # to compare with the original under species
# Out:
# species  island     bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Adelie   Biscoe     34.5            18.1           187.0              2900.0       FEMALE    1
#          Dream      41.5            18.5           201.0              4000.0       MALE      1
#                     42.3            21.2           191.0              4150.0       MALE      1
#                     43.2            18.5           192.0              4100.0       MALE      1
#                     44.1            19.7           196.0              4400.0       MALE      1
#                                                                                             ..
#                     36.0            17.9           190.0              3450.0       FEMALE    1
#                                     18.5           186.0              3100.0       FEMALE    1
#                     36.2            17.3           187.0              3300.0       FEMALE    1
# ...

# %%
penguins_Gentoo = penguins[penguins['species']=='Gentoo']
penguins_Gentoo.value_counts()
# Out:
# species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Gentoo   Biscoe  40.9            13.7           214.0              4650.0       FEMALE    1
#                  49.6            15.0           216.0              4750.0       MALE      1
#                  49.5            16.1           224.0              5650.0       MALE      1
#                  49.4            15.8           216.0              4925.0       MALE      1
#                  49.3            15.7           217.0              5850.0       MALE      1
#                                                                                          ..
#                  45.5            15.0           220.0              5000.0       MALE      1
#                                  14.5           212.0              4750.0       FEMALE    1
#                                  13.9           210.0              4200.0       FEMALE    1
# ...

# %%
penguins_Chinstrap = penguins[penguins['species']=='Chinstrap']
penguins_Chinstrap.value_counts()
# Out:
# species    island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  sex
# Chinstrap  Dream   40.9            16.6           187.0              3200.0       FEMALE    1
#                    50.5            19.6           201.0              4050.0       MALE      1
#                    50.9            19.1           196.0              3550.0       MALE      1
#                                    17.9           196.0              3675.0       FEMALE    1
#                    50.8            19.0           210.0              4100.0       MALE      1
#                                                                                            ..
#                    48.5            17.5           191.0              3400.0       MALE      1
#                    49.0            19.5           210.0              3950.0       MALE      1
#                                    19.6           212.0              4300.0       MALE      1
# ...

# %% [markdown]
# ### Zscore Analysis of the numerical variables of the species subset of the Palmer Penguins
# Z-score analysis was performed on the Adelie, Gentoo and Chintrap  penguin's bill length, bill depth, flipper length and body mass. Only 2 outliers were present, an Adelie penguin with with a flipper length of 210 mm  and a Z-score of 3.075 as against the group mean flipper length of 189.95 mm. the second was a Gentoo penguin with a bill length of  59.3 mm and a z-score of 3.94 as against the group bill length mean of 47.5 mm.

# %%
# Creating a numerical subset of the Adelie penguins columns as a list
peng_Adelie = penguins_Adelie[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# Z-score outlier test on the pen
Adelie_Zscore = stats.zscore(peng_Adelie)

#print (Adelie_Zscore.to_string()) #for viewing

# %%
pspecie = penguins.groupby('species').count()
print (pspecie)
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        151             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        123             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  151
# Chinstrap           68   68
# Gentoo             123  123

# %%
pz = pspecie[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]
print (pz)
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie                151            151                151          151
# Chinstrap              68             68                 68           68
# Gentoo                123            123                123          123

# %%
pz = stats.zscore(pspecie)
print (pz)
# Out:
#              island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie     1.073178        1.073178       1.073178           1.073178
# Chinstrap -1.334221       -1.334221      -1.334221          -1.334221
# Gentoo     0.261043        0.261043       0.261043           0.261043
#
#            body_mass_g       sex
# species
# Adelie        1.073178  1.073178
# Chinstrap    -1.334221 -1.334221
# Gentoo        0.261043  0.261043

# %%
#printing off dataframes with outliers with Z-score outside the +- 3 standard deviation
outliers = (pz > 3) | (pz < -3)
print (outliers)
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie      False           False          False              False
# Chinstrap   False           False          False              False
# Gentoo      False           False          False              False
#
#            body_mass_g    sex
# species
# Adelie           False  False
# Chinstrap        False  False
# Gentoo           False  False

# %%
# Find rows containing outliers in any feature
outliers_any = outliers.any(axis=1)
print(outliers_any)
# Out:
# species
# Adelie       False
# Chinstrap    False
# Gentoo       False
# dtype: bool

# %%
#printing off dataframes with outliers with Z-score outside the +- 3 standard deviation
Outliers_Adelie = (Adelie_Zscore > 3) | (Adelie_Zscore < -3)
print(f"bill length outliers: {peng_Adelie[Outliers_Adelie['bill_length_mm']]}")
print(f"bill depth outliers: {peng_Adelie[Outliers_Adelie['bill_depth_mm']]}")
print(f"flipper length outliers: {peng_Adelie[Outliers_Adelie['flipper_length_mm']]}")
print(f"body mass outliers: {peng_Adelie[Outliers_Adelie['body_mass_g']]}")
print(Adelie_Zscore.at[129, 'flipper_length_mm'])
# Out:
# bill length outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# bill depth outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# flipper length outliers:      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 129            44.1           18.0              210.0       4000.0
# body mass outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# 3.075647798563297

# %%
# Creating a numerical subset of the Gentoo penguins columns as a list
peng_Gentoo = penguins_Gentoo[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# Z-score outlier test on the pen
Gentoo_Zscore = stats.zscore(peng_Gentoo)

#print (Gentoo_Zscore.to_string()) #for viewing

# %%
#printing off dataframes with outliers with Z-score outside the +- 3 standard deviation
Outliers_Gentoo = (Gentoo_Zscore > 3) | (Gentoo_Zscore < -3)
print(f"bill length outliers: {peng_Gentoo[Outliers_Gentoo['bill_length_mm']]}")
print(f"bill depth outliers: {peng_Gentoo[Outliers_Gentoo['bill_depth_mm']]}")
print(f"flipper length outliers: {peng_Gentoo[Outliers_Gentoo['flipper_length_mm']]}")
print(f"body mass outliers: {peng_Gentoo[Outliers_Gentoo['body_mass_g']]}")
print(Gentoo_Zscore.at[253, 'bill_length_mm']) #printing the zscore with the index of the outlier
# Out:
# bill length outliers:      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 253            59.6           17.0              230.0       6050.0
# bill depth outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# flipper length outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# body mass outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# 3.9406726180782026

# %%
# Creating a numerical subset of the Chinstrap penguins columns as a list
peng_Chinstrap = penguins_Chinstrap[['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]

# Z-score outlier test on the pen
Chinstrap_Zscore = stats.zscore(peng_Chinstrap)

#print (Gentoo_Zscore.to_string()) #for viewing

# %%
#printing off dataframes with outliers with Z-score outside the +- 3 standard deviation
Outliers_Chinstrap = (Chinstrap_Zscore > 3) | (Chinstrap_Zscore < -3)
print(f"bill length outliers: {peng_Chinstrap[Outliers_Chinstrap['bill_length_mm']]}")
print(f"bill depth outliers: {peng_Chinstrap[Outliers_Chinstrap['bill_depth_mm']]}")
print(f"flipper length outliers: {peng_Chinstrap[Outliers_Chinstrap['flipper_length_mm']]}")
print(f"body mass outliers: {peng_Chinstrap[Outliers_Chinstrap['body_mass_g']]}")
# Out:
# bill length outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# bill depth outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# flipper length outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []
# body mass outliers: Empty DataFrame
# Columns: [bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g]
# Index: []

# %% [markdown]
# #### Outlier Summary
# The boxplot identified a total of 6 outliers while the Z-score only identified too. It may be good to test for outliers using the [interquartile range](https://www.statology.org/find-outliers-with-iqr/) though not done in this analysis.

# %% [markdown]
# ### Statistical Analysis
#
# The original data was loaded in as a variable 'palmer_penguins', however the cleaned up data was saved to the variable 'penguins' which was used for the rest of the analysis

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# The [Seaborn pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) provides a visual representation of pairwise relationship between variables. The KDE diagonal plot shows the normal distribution of the univariate analysis of the bill length, bill depth, flipper length and body mass.
# The scatterplot shows a linear pairwise relationship exist between the variables.
# The features of the Gentoo species were quite distinct in the scatterplot of the body mass, flipper length and bill depth. The Adelie and Chintrap shared similarities in flipper length and bill depth.

# %%
# importing python warning module
import warnings

# Suppressing the figure layout warning to make it tidy
warnings.filterwarnings('ignore', message='The figure layout has changed to tight')

# createing a pairplot of the cleaned data
sns.pairplot(penguins, hue = 'species', height=3.5, aspect=1.02)

# Creating the main title for the pairplot
plt.suptitle('Palmer penguins body measurement pairplot')
# Out:
# Text(0.5, 0.98, 'Palmer penguins body measurement pairplot')

# %% [markdown]
# ### Correlation Analysis
# This was carried out to establish the relationship between the palmer penguins body mass and flipper length.

# %% [markdown]
# ### Hypothesis
# **Null Hypothesis:** There is a relationship between the the flipper length and the body mass of the palmer penguins. As a penguin's body mass increases, there is a resultant increase in the length of the flippers.
#
# **Alternate Hypothesis** There is no relationship between the the flipper length and the body mass of the palmer penguin population.

# %% [markdown]
# #### Testing the Hypothesis
# #### Correlation Analysis
# A scatterplot and heatmap was used to test the hypothesis below to determine if there is any correlation between the body mass and flipper length of the penguins.

# %% [markdown]
# ##### Scatterplot

# %%
# creating the scatterplot of body mass vs flipper length
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g', hue='species', style = 'sex')

plt.title ('Scatterplot of palmer penguins body mass and flipper length')

#calculating the correlation coefficient
bm_fl_corr = penguins['flipper_length_mm'].corr(penguins['body_mass_g'])
print (bm_fl_corr)
# Out:
# 0.8712017673060111

# %% [markdown]
# ##### Heatmap Correlation Matrix
# This was used to compare the relationship between all the numerical variables in the dataset.

# %%
# Selecting the numerical columns from the DataFrame
peng_numvar = penguins.select_dtypes(include=['float64'])

# Calculating the numerical variable correlation matrix of the penguins
pengnumvar_corrmat = peng_numvar.corr()
print (pengnumvar_corrmat)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
# Creating the heatmap with the correlation matrix
sns.heatmap(pengnumvar_corrmat, annot=True, cmap='coolwarm', fmt=".2f")

# labelling the title
plt.title(' Penguins Dataset Correlation Matrix of Numerical Variables')
# Out:
# Text(0.5, 1.0, ' Penguins Dataset Correlation Matrix of Numerical Variables')

# %% [markdown]
# ##### Correlation Summary

# %% [markdown]
# The correlation of the numerical variable ranged from r = -0.24 to 1. The correlation between the penguins bill length and bill depth was the weakest ( r = -0.24) while the strongest correlation observed (r = 1) was the relationship within each variable and itself. The Pearson's correlation coeffiient for the body mass and the flipper length of the penguins wass r = 0.87 which implies a strong positve correlation betweeen the two variables.  Hence, the null hypothesis was accepted.

# %%
#printing off variables with strong correlation
pengnumvar_corrmat = pengnumvar_corrmat.unstack()
#abs to convert neg corr to pos corr
strong_corr = pengnumvar_corrmat[abs(pengnumvar_corrmat) >= 0.7]   
print (strong_corr)
# Out:
# bill_length_mm     bill_length_mm       1.000000
# bill_depth_mm      bill_depth_mm        1.000000
# flipper_length_mm  flipper_length_mm    1.000000
#                    body_mass_g          0.871202
# body_mass_g        flipper_length_mm    0.871202
#                    body_mass_g          1.000000
# dtype: float64

# %% [markdown]
# #### Regression Analysis
# The linear relationship between two variables x and y can be can be calculated using the formula;
#
# $y = mx + c$
#
# Where m = slope
#
# c = intercept
#
# However, this can be achieved in numpy with the formula;
#
# $ y = mx + c = p_1x^1 + p_o = p_1 x + po$

# %% [markdown]
# #### Adding the regression line to the scatterplot

# %%
# creating the scatterplot of body mass vs flipper length
sns.scatterplot(data=penguins, x='flipper_length_mm', y='body_mass_g', hue='species', style = 'sex')

plt.title ('Palmer penguins body mass vs flipper length\nCorrelation and regression analysis\n')

#calculating the correlation coefficient
bm_fl_corr = penguins['flipper_length_mm'].corr(penguins['body_mass_g'])
print (bm_fl_corr)

#renaming the variables to shorter names
flen = penguins['flipper_length_mm']
bmass = penguins['body_mass_g']

# calculating the slope(m) and intercept (c)
m, c = np.polyfit(flen, bmass, deg=1) # deg = 1 for lin reg

#show
print (f'The slope is {m} and the intercept is {c}')

#creating the best fit line for flength using its min and max values to gen 100 equally spaced values
flen_values = np.linspace(min(flen), max(flen), 100)

# generating the corresponding values for the body mass
bmass_values = m * flen_values + c

# plotting the best fit line for bodymass vs flipper length
plt.plot(flen_values, bmass_values, color='black')
# Out:
# 0.8712017673060111
# The slope is 49.68556640610009 and the intercept is -5780.831358077058

# %% [markdown]
# #### Regression Slope
# The slope was calculated to be 49.68556640610009 and the intercept -5780.831358077058. The penguins' body mass was the dependent variable and the flipper length the independent variable. If other variables remain constant, the slope indicates that for every millimeter increase in the penguins flipper length, there is an expected increase in the penguins' body mass of about 49.68g.

# %% [markdown]
# #### Additional Plots

# %%
#plot 1: 
sns.pairplot(penguins, x_vars=['flipper_length_mm'], y_vars=['body_mass_g'], hue='sex', height=6, aspect=1.02, kind='reg')
plt.title('Relationship between Flipper Length and Body Mass by Sex')


#plot 2:
sns.pairplot(penguins, x_vars=['flipper_length_mm'], y_vars=['body_mass_g'], hue='species',  height=6, aspect=1.02, kind='reg')
plt.title('Relationship between Flipper Length and Body Mass by Species')

#plot 3:
sns.pairplot(penguins, x_vars=['flipper_length_mm'], y_vars=['body_mass_g'], hue='island',  height=6, aspect=1.02, kind='reg')
plt.title('Relationship between Flipper Length and Body Mass by island')
# Out:
# Text(0.5, 1.0, 'Relationship between Flipper Length and Body Mass by island')

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 10))
fig.suptitle ('Palmer Penguins Dataset swarm plots')

#creating chart for each subplot
sns.swarmplot(data=penguins, x='species', y='bill_length_mm', hue = 'sex', ax = ax [0, 0])
sns.swarmplot(data=penguins, x='species', y='bill_depth_mm', hue = 'sex', ax = ax [0, 1])
sns.swarmplot(data=penguins, x='species', y='flipper_length_mm', hue = 'sex', ax = ax [1, 0])
sns.swarmplot(data=penguins, x='species', y='body_mass_g', hue = 'sex', ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 8))
fig.suptitle ('Palmer Penguins Dataset violin plots')

#creating chart for each subplot
sns.violinplot(data=penguins, x='island', y='bill_length_mm', hue = 'sex',  ax = ax [0, 0])
sns.violinplot(data=penguins, x='island', y='bill_depth_mm', hue = 'sex', ax = ax [0, 1])
sns.violinplot(data=penguins, x='island', y='flipper_length_mm', hue = 'sex', ax = ax [1, 0])
sns.violinplot(data=penguins, x='island', y='body_mass_g', hue = 'sex', ax = ax [1, 1])
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 8))
fig.suptitle ('Palmer Penguins Dataset violin plots')

#creating chart for each subplot
sns.violinplot(data=penguins, x='species', y='bill_length_mm', hue = 'sex', split = True, ax = ax [0, 0])
sns.violinplot(data=penguins, x='species', y='bill_depth_mm', hue = 'sex', split = True, ax = ax [0, 1])
sns.violinplot(data=penguins, x='species', y='flipper_length_mm', hue = 'sex', split = True, ax = ax [1, 0])
sns.violinplot(data=penguins, x='species', y='body_mass_g', hue = 'sex', split = True, ax = ax [1, 1])
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ### Conclusion
#
#
# The Palmer penguin dataset was used to demonstrate how raw data can be sourced, explored, manipulated, modelled and visulaized in  order to provide meaningful insights.
# The project outcome can be summarized with these key  points;
#
# - A total of 344 Palmer penguins were studied.
# - The dataset is normally distributed.
# - These penguins habit in Biscoe (n = 168), Dream (n = 124) and Torgersen (n = 52) Islands.
# - The penguins are of three different species; Adelie (n = 152), Gentoo (n = 124) and Chinstrap (n = 68).
# - The penguins were male (n = 168) and female (n = 165).
# - Variables measured were species, sex, island, bill length, bill depth, flipper length and body mass.
# - The bill legth, bill depth, flipper length and body mass are useful features that can be used in classifying penguins with the features of the gentoo penguins being more distinct.
# - Adelie and Chintrap penguin share overalpping characteristics however Chintrap penguins seems to be only resident in Dream Island while the Adelie penguins can be seen in all three islands.
# - The male penguins has generally longer bill length, bill depth, flipper length and weigh more than the female penguins.
# - There is a linear realtionship ranging from wea k to strong between the penguin body measuremnts.
# - There is a strong correlation between the penguins body mass and flipper length (r =0.87).
# - The regression predicts that for every millimeter increase in the penguins flipper length, there is an expected increase in the penguins' body mass of about 49.68g.
# - Panda, Numpy, Matplotlib, Scipy and seaborn are essential libraries used in data analysis.
# - Application of data exploration, manipulation, analysis and visualization provides a stepwise approach to data analysis.

# %% [markdown]
# ### Technologies
# - Visual studio code
# - Cmder
# - Anaconda
# - pylint and pylance for code linting

# %% [markdown]
# ### References
#
# - Atlassian (no date b) How to choose the right data visualization | Atlassian. https://www.atlassian.com/data/charts/how-to-choose-data-visualization#:~:text=Bar%20charts%20are%20used%20when%20a%20variable%20is,when%20a%20variable%20is%20quantitative%2C%20taking%20numeric%20values.
#
# - Atlassian (no date) Essential chart types for data Visualization | Atlassian. https://www.atlassian.com/data/charts/essential-chart-types-for-data-visualization.
#
# - Bevans, R. (2023). Types of variables in Research & Statistics | Examples. https://www.scribbr.com/methodology/types-of-variables/.
#
# - Bobbitt, Z. (2021). How to Make Heatmaps with Seaborn (With Examples). https://www.statology.org/seaborn-heatmap/.
#
# - Bobbitt, Z. (2022). Pandas: How to Fill NaN Values with Mode. https://www.statology.org/pandas-fillna-with-mode/.
#
# - Allen Downey (No date).Classification — Think Bayes. https://allendowney.github.io/ThinkBayes2/chap12.html.
#
# - Ddassun (no date b). GitHub - ddassun/Palmerpenguins-Data-Analysis: A great intro dataset for data exploration & visualization (alternative to iris). https://github.com/ddassun/Palmerpenguins-Data-Analysis.
#
# - Erondu, F. (2022). 'Visualizing the PalmerPenguins Dataset - Fortune Erondu - medium,' Medium, 9 November. https://medium.com/@Fortune_/visualizing-the-palmerpenguins-dataset-d3d70bb619b4.
#
# - Gorman, K.B., Williams, T. and Fraser, W.R. (2014). 'Ecological Sexual Dimorphism and Environmental Variability within a Community of Antarctic Penguins (Genus Pygoscelis),' PloS One, 9(3), p. e90081. https://doi.org/10.1371/journal.pone.0090081.
#
# - Horst, A.M., Hill, A.P. and Gorman, K.B., 2020. palmerpenguins: Palmer Archipelago (Antarctica) penguin data. R package version 0.1. 0. Zenodo.  https://www.allisonhorst. github. io/palmerpenguins.
#
# - Pandas (2024). How to select, filter, and subset data in Pandas dataframes (2021). https://practicaldatascience.co.uk/data-science/how-to-select-filter-and-subset-data-in-pandas-dataframes.
#
# - Matt Macarty (2021). Linear Regression Model Techniques with Python, NumPy, pandas and Seaborn. https://www.youtube.com/watch?v=EMIyRmrPWJQ.
#
# - Nik (2023). How to calculate a Z-Score in Python (4 ways). https://datagy.io/python-z-score/.
#
# - Nik (2023a) Calculate and plot a correlation matrix in Python and Pandas. https://datagy.io/python-correlation-matrix/.
#
# - Numpy.polyfit — NumPy v1.26 Manual (no date). https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html.
#
# - Pandas(2024). Pandas.DataFrame.duplicated — pandas 2.2.2 documentation (no date). https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html.
#
# - Python, R. (2023) Plot With pandas: Python Data Visualization for Beginners. https://realpython.com/pandas-plot-python/#survey-your-data.
#
# - seaborn.boxplot — seaborn 0.13.2 documentation (no date b). https://seaborn.pydata.org/generated/seaborn.boxplot.html.
#
# - seaborn.boxplot — seaborn 0.13.2 documentation (no date d). https://seaborn.pydata.org/generated/seaborn.boxplot.html.
#
# - seaborn.pairplot — seaborn 0.13.2 documentation (no date). https://seaborn.pydata.org/generated/seaborn.pairplot.html.
#
# - seaborn.scatterplot — seaborn 0.13.2 documentation (no date). https://seaborn.pydata.org/generated/seaborn.scatterplot.html.
#
# - Selvaraj, N. (2023) A Beginner’s Guide to data analysis in Python. https://365datascience.com/tutorials/python-tutorials/data-analysis-python/.
#
# - Team, D. (2022) Data cleaning tutorial. https://www.datacamp.com/tutorial/tutorial-data-cleaning-tutorial.
#
# - Vahi, Y. (2022) 'Exploratory Data Analysis (EDA): a complete roadmap to cleaning data,' Medium, 6 January. https://medium.com/codex/exploratory-data-analysis-a-roadmap-for-cleaning-3e01a0d694.
#
# - Valcheva, S. (2024) Statistical Methods for Data Analysis: a Comprehensive Guide. https://www.intellspot.com/statistical-methods/.

# %% [markdown]
# ***
# ## End
